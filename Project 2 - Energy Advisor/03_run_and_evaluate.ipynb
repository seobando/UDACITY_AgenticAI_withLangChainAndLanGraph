# %% [markdown]
# # EcoHome Energy Advisor - Agent Run & Evaluation
#
# In this notebook, you'll run the Energy Advisor agent with various real-world scenarios and see how it helps customers optimize their energy usage.
#
# ## Learning Objectives
# - Create the agent's instructions
# - Run the Energy Advisor with different types of questions
# - Evaluate response quality and accuracy
# - Measure tool usage effectiveness
# - Identify areas for improvement
# - Implement evaluation metrics
#
# ## Evaluation Criteria
# - **Accuracy**: Correct information and calculations
# - **Relevance**: Responses address the user's question
# - **Completeness**: Comprehensive answers with actionable advice
# - **Tool Usage**: Appropriate use of available tools
# - **Reasoning**: Clear explanation of recommendations

# %% [markdown]
# ## 1. Import and Initialize

# %%
from datetime import datetime
from agent import Agent

# %%
## TODO: Create the agent's instructions

ECOHOME_SYSTEM_PROMPT = """You are the EcoHome Energy Advisor, an AI assistant specialized in helping homeowners optimize their energy usage, reduce costs, and maximize the benefits of solar power.

Your primary goals are:
1. Help users minimize electricity costs by leveraging time-of-use pricing
2. Maximize the use of solar-generated electricity
3. Provide actionable recommendations for energy optimization
4. Calculate potential savings from energy-efficient practices

Available Tools:
- get_weather_forecast: Get weather forecasts including solar irradiance data
- get_electricity_prices: Get time-of-use electricity pricing by hour
- query_energy_usage: Query historical energy consumption data
- query_solar_generation: Query historical solar generation data
- get_recent_energy_summary: Get summary of recent energy usage and generation
- search_energy_tips: Search for energy-saving tips and best practices
- calculate_energy_savings: Calculate potential savings from optimizations. IMPORTANT: When users ask about savings from reducing usage (e.g., "if I reduce X by Y%, how much would I save?"), you MUST:
  1. First try get_recent_energy_summary to get current usage data (it provides device breakdown with consumption_kwh)
  2. If that doesn't have the specific device, use query_energy_usage with a recent date range (e.g., last 30 days)
  3. Extract monthly usage from the data
  4. Calculate the optimized usage based on the reduction percentage
  5. Then use calculate_energy_savings tool with the current usage, optimized usage, and device type
  6. Present the calculated savings to the user

Guidelines:
- Always use relevant tools to gather current data before making recommendations
- Consider weather forecasts when recommending solar-dependent activities
- Factor in electricity pricing (peak/off-peak) when suggesting optimal times
- Provide specific time recommendations when relevant
- Include cost calculations and savings estimates when possible
- Be clear, concise, and actionable in your responses
- If you need location information, ask the user or use the context provided
- Always explain your reasoning behind recommendations
- When users ask about potential savings from reducing energy usage, you MUST use the calculate_energy_savings tool to provide accurate calculations

When making recommendations:
- Prioritize using solar power when available
- Suggest off-peak hours for high-energy activities when solar isn't available
- Consider both cost savings and environmental impact
- Provide specific time windows for optimal actions

For savings calculations:
- If a user asks "how much would I save if I reduce [device] usage by X%", you MUST:
  1. First try get_recent_energy_summary to get current usage data (it provides device breakdown)
  2. If that doesn't have the specific device, then use query_energy_usage with a recent date range (e.g., last 30 days)
  3. Extract the monthly usage from the data (if daily, multiply by 30; if weekly, multiply by 4.33)
  4. Calculate the reduced usage (current * (1 - X/100))
  5. Use calculate_energy_savings tool with the current usage, optimized usage, and device type
  6. Report the savings including monthly and annual projections
- IMPORTANT: If query_energy_usage returns no data, use get_recent_energy_summary instead. Do not keep trying different date ranges.
"""

# %%
ecohome_agent = Agent(
    instructions=ECOHOME_SYSTEM_PROMPT,
)

# %%
response = ecohome_agent.invoke(
    question="When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
    context="Location: San Francisco, CA"
)

# %%
print(response["messages"][-1].content)
# Out:
# To minimize costs and maximize solar power when charging your electric car tomorrow (October 7, 2023), here are the key insights:
#
# ### Solar Power Generation
# - **Peak Solar Generation**: The solar irradiance data indicates that the best solar generation will occur between **10 AM and 3 PM**. The highest solar irradiance is expected at **1 PM** with a value of **614.1 W/m²**.
#
# ### Electricity Pricing
# - **Off-Peak Rates**: The off-peak rates are significantly lower than peak rates. Here are the relevant rates:
#   - **Off-Peak (Midnight to 6 AM)**: Rates range from **$0.1105 to $0.1295**.
#   - **Peak (6 AM to 7 PM)**: Rates are higher, peaking at **$0.2494 at 5 PM**.
#
# ### Recommendations
# 1. **Charge During Peak Solar Hours**:
#    - **Best Time to Charge**: **10 AM to 3 PM**. This is when solar generation is at its highest, allowing you to utilize solar power for charging your electric car.
#    - **Optimal Hour**: Start charging around **10 AM** to take advantage of the increasing solar generation.
#
# 2. **Consider Off-Peak Charging**:
#    - If you need to charge outside of solar hours, consider charging during the **off-peak hours** (before 6 AM or after 10 PM) to minimize costs.
#
# ### Summary
# - **Charge your electric car from 10 AM to 3 PM** to maximize solar power usage.
# - If charging outside of these hours, opt for off-peak times to save on electricity costs.
#
# This strategy will help you reduce your electricity costs while maximizing the use of renewable solar energy!

# %%
print("TOOLS:")
from langchain_core.messages import AIMessage, ToolMessage
for msg in response["messages"]:
    # Check if it's an AIMessage with tool calls
    if isinstance(msg, AIMessage) and hasattr(msg, 'tool_calls') and msg.tool_calls:
        for tool_call in msg.tool_calls:
            print("-", tool_call.get("name", "unknown"))
    # Check if it's a ToolMessage
    elif isinstance(msg, ToolMessage):
        # ToolMessage doesn't have name directly, but we can check the tool_call_id
        # The tool name is usually in the corresponding AIMessage
        pass
# Out:
# TOOLS:
# - get_weather_forecast
# - get_electricity_prices

# %% [markdown]
# ## 2. Define Test Cases

# %%
# TODO: Define comprehensive test cases for the Energy Advisor
# Create 10 test cases covering different scenarios:
# - EV charging optimization
# - Thermostat settings
# - Appliance scheduling
# - Solar power maximization
# - Cost savings calculations

test_cases = [
    {
        "id": "ev_charging_1",
        "question": "When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "The response should contain time recommendation, cost analysis and solar consideration",
    },
    {
        "id": "ev_charging_2",
        "question": "I need to charge my EV from 20% to 80% battery. When is the cheapest time to do this today?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast"],
        "expected_response": "The response should recommend specific hours with cost analysis",
    },
    {
        "id": "thermostat_1",
        "question": "What's the optimal thermostat setting for today to balance comfort and energy costs?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices", "get_recent_energy_summary"],
        "expected_response": "The response should provide temperature recommendations with cost considerations",
    },
    {
        "id": "appliance_scheduling_1",
        "question": "When should I run my dishwasher and washing machine to save the most money?",
        "expected_tools": ["get_electricity_prices", "get_weather_forecast"],
        "expected_response": "The response should recommend optimal times considering pricing and solar availability",
    },
    {
        "id": "solar_maximization_1",
        "question": "How can I maximize my use of solar power tomorrow?",
        "expected_tools": ["get_weather_forecast", "query_solar_generation", "get_electricity_prices"],
        "expected_response": "The response should provide strategies to align energy usage with solar generation",
    },
    {
        "id": "cost_analysis_1",
        "question": "How much did I spend on electricity last week and what was my biggest energy expense?",
        "expected_tools": ["query_energy_usage", "get_recent_energy_summary"],
        "expected_response": "The response should provide cost breakdown and identify highest consumption areas",
    },
    {
        "id": "energy_tips_1",
        "question": "What are the best ways to reduce my HVAC energy consumption?",
        "expected_tools": ["search_energy_tips", "query_energy_usage"],
        "expected_response": "The response should provide actionable tips for HVAC energy savings",
    },
    {
        "id": "savings_calculation_1",
        "question": "If I reduce my air conditioning usage by 30%, how much money would I save per month? Please calculate the exact savings using my current AC usage data.",
        "expected_tools": ["query_energy_usage", "calculate_energy_savings"],
        "expected_response": "The response should calculate and present potential monthly savings using the calculate_energy_savings tool",
    },
    {
        "id": "solar_generation_1",
        "question": "How much solar power did I generate last month and how does it compare to my usage?",
        "expected_tools": ["query_solar_generation", "query_energy_usage"],
        "expected_response": "The response should compare generation vs consumption with analysis",
    },
    {
        "id": "comprehensive_optimization_1",
        "question": "Give me a comprehensive plan to optimize my energy usage for the next 3 days considering weather and pricing.",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices", "get_recent_energy_summary", "search_energy_tips"],
        "expected_response": "The response should provide a detailed multi-day optimization plan",
    },
]

# %%
if len(test_cases) < 10:
    raise ValueError("You MUST have at least 10 test cases")

# %% [markdown]
# ## 3. Run Agent Tests

# %%
CONTEXT = "Location: San Francisco, CA"

# %%
# Run the agent tests
# For each test case, call the agent and collect the response
# Store results for evaluation

print("=== Running Agent Tests ===")
test_results = []

for i, test_case in enumerate(test_cases):
    print(f"\nTest {i+1}: {test_case['id']}")
    print(f"Question: {test_case['question']}")
    print("-" * 50)
    
    try:
        # Call the agent
        response = ecohome_agent.invoke(
            question=test_case['question'],
            context=CONTEXT
        )
        
        # Store the result
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': response,
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat()
        }
        test_results.append(result)
                
    except Exception as e:
        print(f"Error: {e}")
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': f"Error: {str(e)}",
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat(),
            'error': str(e)
        }
        test_results.append(result)

print(f"\nCompleted {len(test_results)} tests")
# Out:
# === Running Agent Tests ===
#
# Test 1: ev_charging_1
# Question: When should I charge my electric car tomorrow to minimize cost and maximize solar power?
# --------------------------------------------------
#
# Test 2: ev_charging_2
# Question: I need to charge my EV from 20% to 80% battery. When is the cheapest time to do this today?
# --------------------------------------------------
#
# Test 3: thermostat_1
# Question: What's the optimal thermostat setting for today to balance comfort and energy costs?
# --------------------------------------------------
#
# Test 4: appliance_scheduling_1
# Question: When should I run my dishwasher and washing machine to save the most money?
# --------------------------------------------------
#
# Test 5: solar_maximization_1
# Question: How can I maximize my use of solar power tomorrow?
# --------------------------------------------------
#
# Test 6: cost_analysis_1
# Question: How much did I spend on electricity last week and what was my biggest energy expense?
# --------------------------------------------------
#
# Test 7: energy_tips_1
# Question: What are the best ways to reduce my HVAC energy consumption?
# --------------------------------------------------
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given
# Test 8: savings_calculation_1
# Question: If I reduce my air conditioning usage by 30%, how much money would I save per month? Please calculate the exact savings using my current AC usage data.
# --------------------------------------------------
#
# Test 9: solar_generation_1
# Question: How much solar power did I generate last month and how does it compare to my usage?
# --------------------------------------------------
#
# Test 10: comprehensive_optimization_1
# Question: Give me a comprehensive plan to optimize my energy usage for the next 3 days considering weather and pricing.
# --------------------------------------------------
#
# Completed 10 tests

# %%
test_results
# Out:
# [{'test_id': 'ev_charging_1',
#   'question': 'When should I charge my electric car tomorrow to minimize cost and maximize solar power?',
#   'response': {'messages': [SystemMessage(content='You are the EcoHome Energy Advisor, an AI assistant specialized in helping homeowners optimize their energy usage, reduce costs, and maximize the benefits of solar power.\n\nYour primary goals are:\n1. Help users minimize electricity costs by leveraging time-of-use pricing\n2. Maximize the use of solar-generated electricity\n3. Provide actionable recommendations for energy optimization\n4. Calculate potential savings from energy-efficient practices\n\nAvailable Tools:\n- get_weather_forecast: Get weather forecasts including solar irradiance data\n- get_electricity_prices: Get time-of-use electricity pricing by hour\n- query_energy_usage: Query historical energy consumption data\n- query_solar_generation: Query historical solar generation data\n- get_recent_energy_summary: Get summary of recent energy usage and generation\n- search_energy_tips: Search for energy-saving tips and best practices\n- calculate_energy_savings: Calculate potential savings from optimizations. IMPORTANT: When users ask about savings from reducing usage (e.g., "if I reduce X by Y%, how much would I save?"), you MUST:\n  1. First use query_energy_usage to get current usage data for the device/type\n  2. Calculate the optimized usage based on the reduction percentage\n  3. Then use calculate_energy_savings tool with the current usage, optimized usage, and device type\n  4. Present the calculated savings to the user\n\nGuidelines:\n- Always use relevant tools to gather current data before making recommendations\n- Consider weather forecasts when recommending solar-dependent activities\n- Factor in electricity pricing (peak/off-peak) when suggesting optimal times\n- Provide specific time recommendations when relevant\n- Include cost calculations and savings estimates when possible\n- Be clear, concise, and actionable in your responses\n- If you need location information, ask the user or use the context provided\n- Always explain your reasoning behind recommendations\n- When users ask about potential savings from reducing energy usage, you MUST use the calculate_energy_savings tool to provide accurate calculations\n\nWhen making recommendations:\n- Prioritize using solar power when available\n- Suggest off-peak hours for high-energy activities when solar isn\'t available\n- Consider both cost savings and environmental impact\n- Provide specific time windows for optimal actions\n\nFor savings calculations:\n- If a user asks "how much would I save if I reduce [device] usage by X%", you MUST:\n  1. Query current energy usage for that device type\n  2. Calculate the reduced usage (current * (1 - X/100))\n  3. Use calculate_energy_savings tool with these values\n  4. Report the savings including monthly and annual projections\n', id='2b94ee2d-8cba-492e-b620-3560afb4a7d0'),
#     SystemMessage(content='Additional context: Location: San Francisco, CA', id='fc046c5e-9e0c-4c4e-a599-97ae27c2ba5e'),
#     HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', id='8f4a1512-e219-4be8-aa8b-2ce6dbca4d07'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_nmtimK9QezHXbS5nJ1tMQUci', 'function': {'arguments': '{"location": "San Francisco, CA", "days": 1}', 'name': 'get_weather_forecast'}, 'type': 'function'}, {'id': 'call_0MSEBoXLANxOCVlV5asUsMzk', 'function': {'arguments': '{"date": "2023-10-07"}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 1594, 'total_tokens': 1655, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1536}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-2e2bc9cc-bc83-44e0-b89b-569a053417a3-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_nmtimK9QezHXbS5nJ1tMQUci', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_0MSEBoXLANxOCVlV5asUsMzk', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1594, 'output_tokens': 61, 'total_tokens': 1655}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 18, "condition": "sunny", "humidity": 64, "wind_speed": 12.5}, "hourly": [{"hour": 0, "temperature_c": 11.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 59, "wind_speed": 10.9}, {"hour": 1, "temperature_c": 12.1, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 67, "wind_speed": 6.9}, {"hour": 2, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 69, "wind_speed": 19.2}, {"hour": 3, "temperature_c": 13.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 74, "wind_speed": 9.1}, {"hour": 4, "temperature_c": 12.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 67, "wind_speed": 10.1}, {"hour": 5, "temperature_c": 13.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 61, "wind_speed": 3.8}, {"hour": 6, "temperature_c": 13.7, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 64, "wind_speed": 11.5}, {"hour": 7, "temperature_c": 13.9, "condition": "sunny", "solar_irradiance": 43.5, "humidity": 74, "wind_speed": 10.2}, {"hour": 8, "temperature_c": 16.7, "condition": "cloudy", "solar_irradiance": 255.7, "humidity": 66, "wind_speed": 5.3}, {"hour": 9, "temperature_c": 18.8, "condition": "cloudy", "solar_irradiance": 154.5, "humidity": 54, "wind_speed": 6.0}, {"hour": 10, "temperature_c": 16.5, "condition": "sunny", "solar_irradiance": 269.6, "humidity": 56, "wind_speed": 16.1}, {"hour": 11, "temperature_c": 20.5, "condition": "sunny", "solar_irradiance": 331.5, "humidity": 62, "wind_speed": 20.0}, {"hour": 12, "temperature_c": 20.8, "condition": "sunny", "solar_irradiance": 615.9, "humidity": 65, "wind_speed": 16.8}, {"hour": 13, "temperature_c": 19.1, "condition": "sunny", "solar_irradiance": 627.2, "humidity": 68, "wind_speed": 19.7}, {"hour": 14, "temperature_c": 21.2, "condition": "partly_cloudy", "solar_irradiance": 495.3, "humidity": 66, "wind_speed": 17.9}, {"hour": 15, "temperature_c": 18.9, "condition": "sunny", "solar_irradiance": 358.4, "humidity": 61, "wind_speed": 16.5}, {"hour": 16, "temperature_c": 18.1, "condition": "sunny", "solar_irradiance": 247.9, "humidity": 64, "wind_speed": 15.9}, {"hour": 17, "temperature_c": 19.7, "condition": "sunny", "solar_irradiance": 63.7, "humidity": 63, "wind_speed": 7.2}, {"hour": 18, "temperature_c": 23.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 55, "wind_speed": 3.5}, {"hour": 19, "temperature_c": 11.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 70, "wind_speed": 13.2}, {"hour": 20, "temperature_c": 12.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 68, "wind_speed": 23.7}, {"hour": 21, "temperature_c": 11.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 64, "wind_speed": 9.4}, {"hour": 22, "temperature_c": 13.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 57, "wind_speed": 10.0}, {"hour": 23, "temperature_c": 13.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 66, "wind_speed": 8.3}]}', name='get_weather_forecast', id='e51c8428-033f-48fd-9b20-500e9b2b2466', tool_call_id='call_nmtimK9QezHXbS5nJ1tMQUci'),
#     ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.123, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1235, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1149, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1138, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.12279999999999999, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1285, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1744, "period": "peak", "demand_charge": 0.07}, {"hour": 7, "rate": 0.18839999999999998, "period": "peak", "demand_charge": 0.0385}, {"hour": 8, "rate": 0.1843, "period": "peak", "demand_charge": 0.0909}, {"hour": 9, "rate": 0.1891, "period": "peak", "demand_charge": 0.0408}, {"hour": 10, "rate": 0.1792, "period": "peak", "demand_charge": 0.0662}, {"hour": 11, "rate": 0.175, "period": "peak", "demand_charge": 0.0334}, {"hour": 12, "rate": 0.18789999999999998, "period": "peak", "demand_charge": 0.0577}, {"hour": 13, "rate": 0.1749, "period": "peak", "demand_charge": 0.0812}, {"hour": 14, "rate": 0.1742, "period": "peak", "demand_charge": 0.0825}, {"hour": 15, "rate": 0.1732, "period": "peak", "demand_charge": 0.0203}, {"hour": 16, "rate": 0.1843, "period": "peak", "demand_charge": 0.036}, {"hour": 17, "rate": 0.2471, "period": "peak", "demand_charge": 0.1447}, {"hour": 18, "rate": 0.23329999999999998, "period": "peak", "demand_charge": 0.0866}, {"hour": 19, "rate": 0.2419, "period": "peak", "demand_charge": 0.1357}, {"hour": 20, "rate": 0.2424, "period": "peak", "demand_charge": 0.0536}, {"hour": 21, "rate": 0.1886, "period": "peak", "demand_charge": 0.0456}, {"hour": 22, "rate": 0.1276, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1191, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='6c8f61c4-775d-4fa0-a557-52a78fc229ff', tool_call_id='call_0MSEBoXLANxOCVlV5asUsMzk'),
#     AIMessage(content='To minimize costs and maximize solar power when charging your electric car tomorrow (October 7, 2023), here are the key insights:\n\n### Solar Power Generation\n- **Peak Solar Generation**: The solar irradiance data indicates that the best solar generation will occur between **10 AM and 2 PM**. During this time, solar power production will be at its highest, especially around **12 PM** when it reaches **615.9 W/m²**.\n\n### Electricity Pricing\n- **Time-of-Use Rates**:\n  - **Peak Rates** (higher costs): \n    - 6 AM - 6 PM (with the highest rate at 5 PM: **$0.2471/kWh**)\n  - **Off-Peak Rates** (lower costs): \n    - 12 AM - 6 AM and 10 PM - 12 AM (lowest rate at 2 AM: **$0.1149/kWh**)\n  \n### Recommendations\n1. **Charge During Solar Peak**: \n   - **Best Time to Charge**: **10 AM to 2 PM**. This is when solar generation is highest, allowing you to utilize solar energy for charging your car, reducing reliance on grid electricity.\n\n2. **Consider Off-Peak Charging**: \n   - If you need to charge outside of solar hours, consider charging during off-peak hours (e.g., **12 AM - 6 AM** or **10 PM - 12 AM**) to take advantage of lower rates.\n\n### Summary\n- **Optimal Charging Window**: **10 AM to 2 PM** to maximize solar power usage.\n- **Alternative Off-Peak Charging**: **12 AM - 6 AM** or **10 PM - 12 AM** for lower costs.\n\nBy following this strategy, you can effectively minimize your electricity costs while maximizing the use of solar energy for your electric car charging.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 393, 'prompt_tokens': 3722, 'total_tokens': 4115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1536}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'stop', 'logprobs': None}, id='run-2ffccbd1-1065-4b3a-936b-ca91091c55ac-0', usage_metadata={'input_tokens': 3722, 'output_tokens': 393, 'total_tokens': 4115})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'The response should contain time recommendation, cost analysis and solar consideration',
#   'timestamp': '2025-11-09T12:54:29.212888'},
#  {'test_id': 'ev_charging_2',
#   'question': 'I need to charge my EV from 20% to 80% battery. When is the cheapest time to do this today?',
#   'response': {'messages': [SystemMessage(content='You are the EcoHome Energy Advisor, an AI assistant specialized in helping homeowners optimize their energy usage, reduce costs, and maximize the benefits of solar power.\n\nYour primary goals are:\n1. Help users minimize electricity costs by leveraging time-of-use pricing\n2. Maximize the use of solar-generated electricity\n3. Provide actionable recommendations for energy optimization\n4. Calculate potential savings from energy-efficient practices\n\nAvailable Tools:\n- get_weather_forecast: Get weather forecasts including solar irradiance data\n- get_electricity_prices: Get time-of-use electricity pricing by hour\n- query_energy_usage: Query historical energy consumption data\n- query_solar_generation: Query historical solar generation data\n- get_recent_energy_summary: Get summary of recent energy usage and generation\n- search_energy_tips: Search for energy-saving tips and best practices\n- calculate_energy_savings: Calculate potential savings from optimizations. IMPORTANT: When users ask about savings from reducing usage (e.g., "if I reduce X by Y%, how much would I save?"), you MUST:\n  1. First use query_energy_usage to get current usage data for the device/type\n  2. Calculate the optimized usage based on the reduction percentage\n  3. Then use calculate_energy_savings tool with the current usage, optimized usage, and device type\n  4. Present the calculated savings to the user\n\nGuidelines:\n- Always use relevant tools to gather current data before making recommendations\n- Consider weather forecasts when recommending solar-dependent activities\n- Factor in electricity pricing (peak/off-peak) when suggesting optimal times\n- Provide specific time recommendations when relevant\n- Include cost calculations and savings estimates when possible\n- Be clear, concise, and actionable in your responses\n- If you need location information, ask the user or use the context provided\n- Always explain your reasoning behind recommendations\n- When users ask about potential savings from reducing energy usage, you MUST use the calculate_energy_savings tool to provide accurate calculations\n\nWhen making recommendations:\n- Prioritize using solar power when available\n- Suggest off-peak hours for high-energy activities when solar isn\'t available\n- Consider both cost savings and environmental impact\n- Provide specific time windows for optimal actions\n\nFor savings calculations:\n- If a user asks "how much would I save if I reduce [device] usage by X%", you MUST:\n  1. Query current energy usage for that device type\n  2. Calculate the reduced usage (current * (1 - X/100))\n  3. Use calculate_energy_savings tool with these values\n  4. Report the savings including monthly and annual projections\n', id='95e2d4bf-05b2-4584-994a-d0f965512158'),
#     SystemMessage(content='Additional context: Location: San Francisco, CA', id='dc71f9bb-f5b6-424b-8f33-23214db1c9e1'),
#     HumanMessage(content='I need to charge my EV from 20% to 80% battery. When is the cheapest time to do this today?', id='8e6d78f6-dfd0-44fb-b1d9-d7571b61b253'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_b9qgcn8E6Eab962Vf5RZwmxq', 'function': {'arguments': '{"date":"2023-10-05"}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 1604, 'total_tokens': 1626, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1536}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-1f1bfa21-164f-4773-b3e4-7c2c88d96200-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2023-10-05'}, 'id': 'call_b9qgcn8E6Eab962Vf5RZwmxq', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1604, 'output_tokens': 22, 'total_tokens': 1626}),
#     ToolMessage(content='{"date": "2023-10-05", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1288, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.11399999999999999, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.1185, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.129, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1109, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1268, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1837, "period": "peak", "demand_charge": 0.0477}, {"hour": 7, "rate": 0.1858, "period": "peak", "demand_charge": 0.0894}, {"hour": 8, "rate": 0.18109999999999998, "period": "peak", "demand_charge": 0.0642}, {"hour": 9, "rate": 0.1883, "period": "peak", "demand_charge": 0.0965}, {"hour": 10, "rate": 0.1787, "period": "peak", "demand_charge": 0.0992}, {"hour": 11, "rate": 0.1717, "period": "peak", "demand_charge": 0.0323}, {"hour": 12, "rate": 0.1777, "period": "peak", "demand_charge": 0.0554}, {"hour": 13, "rate": 0.1794, "period": "peak", "demand_charge": 0.0441}, {"hour": 14, "rate": 0.1704, "period": "peak", "demand_charge": 0.0302}, {"hour": 15, "rate": 0.1746, "period": "peak", "demand_charge": 0.0723}, {"hour": 16, "rate": 0.1722, "period": "peak", "demand_charge": 0.0757}, {"hour": 17, "rate": 0.2334, "period": "peak", "demand_charge": 0.0688}, {"hour": 18, "rate": 0.2326, "period": "peak", "demand_charge": 0.0532}, {"hour": 19, "rate": 0.2475, "period": "peak", "demand_charge": 0.0835}, {"hour": 20, "rate": 0.2395, "period": "peak", "demand_charge": 0.1123}, {"hour": 21, "rate": 0.17729999999999999, "period": "peak", "demand_charge": 0.0385}, {"hour": 22, "rate": 0.12179999999999999, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1255, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='784afecd-69ea-4060-bee8-7a2cf97f9193', tool_call_id='call_b9qgcn8E6Eab962Vf5RZwmxq'),
#     AIMessage(content="To charge your EV from 20% to 80%, you'll need to consider the cheapest time to do so based on today's electricity pricing. Here are the rates for today, October 5, 2023:\n\n- **Off-Peak Hours (Cheapest Rates)**:\n  - 0:00 - 1:00 AM: $0.1288/kWh\n  - 1:00 - 2:00 AM: $0.1140/kWh\n  - 2:00 - 3:00 AM: $0.1185/kWh\n  - 3:00 - 4:00 AM: $0.1290/kWh\n  - 4:00 - 5:00 AM: $0.1109/kWh\n  - 5:00 - 6:00 AM: $0.1268/kWh\n  - 10:00 - 11:00 PM: $0.1773/kWh\n  - 11:00 - 12:00 AM: $0.1218/kWh\n  - 12:00 - 1:00 AM: $0.1255/kWh\n\n- **Peak Hours (More Expensive Rates)**:\n  - 6:00 AM - 10:00 PM: Rates range from $0.1704 to $0.2475/kWh\n\n### Recommendation:\nThe cheapest time to charge your EV today would be between **4:00 AM and 5:00 AM** at a rate of **$0.1109/kWh**. \n\nIf you can charge your EV during this time, you'll save on electricity costs significantly compared to peak hours.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 350, 'prompt_tokens': 2460, 'total_tokens': 2810, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1664}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'stop', 'logprobs': None}, id='run-9f64a1ec-8d5c-49a3-b5de-8d55eaa84106-0', usage_metadata={'input_tokens': 2460, 'output_tokens': 350, 'total_tokens': 2810})]},
#   'expected_tools': ['get_electricity_prices', 'get_weather_forecast'],
#   'expected_response': 'The response should recommend specific hours with cost analysis',
#   'timestamp': '2025-11-09T12:54:37.997138'},
#  {'test_id': 'thermostat_1',
#   'question': "What's the optimal thermostat setting for today to balance comfort and energy costs?",
#   'response': {'messages': [SystemMessage(content='You are the EcoHome Energy Advisor, an AI assistant specialized in helping homeowners optimize their energy usage, reduce costs, and maximize the benefits of solar power.\n\nYour primary goals are:\n1. Help users minimize electricity costs by leveraging time-of-use pricing\n2. Maximize the use of solar-generated electricity\n3. Provide actionable recommendations for energy optimization\n4. Calculate potential savings from energy-efficient practices\n\nAvailable Tools:\n- get_weather_forecast: Get weather forecasts including solar irradiance data\n- get_electricity_prices: Get time-of-use electricity pricing by hour\n- query_energy_usage: Query historical energy consumption data\n- query_solar_generation: Query historical solar generation data\n- get_recent_energy_summary: Get summary of recent energy usage and generation\n- search_energy_tips: Search for energy-saving tips and best practices\n- calculate_energy_savings: Calculate potential savings from optimizations. IMPORTANT: When users ask about savings from reducing usage (e.g., "if I reduce X by Y%, how much would I save?"), you MUST:\n  1. First use query_energy_usage to get current usage data for the device/type\n  2. Calculate the optimized usage based on the reduction percentage\n  3. Then use calculate_energy_savings tool with the current usage, optimized usage, and device type\n  4. Present the calculated savings to the user\n\nGuidelines:\n- Always use relevant tools to gather current data before making recommendations\n- Consider weather forecasts when recommending solar-dependent activities\n- Factor in electricity pricing (peak/off-peak) when suggesting optimal times\n- Provide specific time recommendations when relevant\n- Include cost calculations and savings estimates when possible\n- Be clear, concise, and actionable in your responses\n- If you need location information, ask the user or use the context provided\n- Always explain your reasoning behind recommendations\n- When users ask about potential savings from reducing energy usage, you MUST use the calculate_energy_savings tool to provide accurate calculations\n\nWhen making recommendations:\n- Prioritize using solar power when available\n- Suggest off-peak hours for high-energy activities when solar isn\'t available\n- Consider both cost savings and environmental impact\n- Provide specific time windows for optimal actions\n\nFor savings calculations:\n- If a user asks "how much would I save if I reduce [device] usage by X%", you MUST:\n  1. Query current energy usage for that device type\n  2. Calculate the reduced usage (current * (1 - X/100))\n  3. Use calculate_energy_savings tool with these values\n  4. Report the savings including monthly and annual projections\n', id='2ec01146-d9ef-443b-a31a-d523c66fc96c'),
#     SystemMessage(content='Additional context: Location: San Francisco, CA', id='f2c5e782-cf36-430c-8e4f-d648d1acc0d5'),
#     HumanMessage(content="What's the optimal thermostat setting for today to balance comfort and energy costs?", id='e86ec874-194e-4919-af18-fd48b9c234d8'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Mlgdhk7KuffdLs7xaJTm4G4d', 'function': {'arguments': '{"location":"San Francisco, CA","days":1}', 'name': 'get_weather_forecast'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1592, 'total_tokens': 1615, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1536}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7a37e3e7-0918-4753-8aed-e8269e213fff-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_Mlgdhk7KuffdLs7xaJTm4G4d', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1592, 'output_tokens': 23, 'total_tokens': 1615}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 1, "current": {"temperature_c": 18, "condition": "sunny", "humidity": 75, "wind_speed": 8.9}, "hourly": [{"hour": 0, "temperature_c": 12.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 73, "wind_speed": 6.1}, {"hour": 1, "temperature_c": 11.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 75, "wind_speed": 10.5}, {"hour": 2, "temperature_c": 11.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 85, "wind_speed": 23.3}, {"hour": 3, "temperature_c": 10.7, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 82, "wind_speed": 16.5}, {"hour": 4, "temperature_c": 10.7, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 65, "wind_speed": 10.4}, {"hour": 5, "temperature_c": 11.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 68, "wind_speed": 20.0}, {"hour": 6, "temperature_c": 17.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 73, "wind_speed": 24.9}, {"hour": 7, "temperature_c": 15.1, "condition": "sunny", "solar_irradiance": 122.0, "humidity": 73, "wind_speed": 15.3}, {"hour": 8, "temperature_c": 16.1, "condition": "sunny", "solar_irradiance": 136.2, "humidity": 78, "wind_speed": 9.1}, {"hour": 9, "temperature_c": 14.6, "condition": "sunny", "solar_irradiance": 374.1, "humidity": 81, "wind_speed": 22.8}, {"hour": 10, "temperature_c": 15.8, "condition": "sunny", "solar_irradiance": 301.7, "humidity": 73, "wind_speed": 3.4}, {"hour": 11, "temperature_c": 15.6, "condition": "sunny", "solar_irradiance": 578.7, "humidity": 81, "wind_speed": 16.3}, {"hour": 12, "temperature_c": 20.2, "condition": "sunny", "solar_irradiance": 551.8, "humidity": 70, "wind_speed": 25.0}, {"hour": 13, "temperature_c": 18.7, "condition": "cloudy", "solar_irradiance": 495.7, "humidity": 69, "wind_speed": 9.0}, {"hour": 14, "temperature_c": 19.9, "condition": "cloudy", "solar_irradiance": 315.8, "humidity": 68, "wind_speed": 20.0}, {"hour": 15, "temperature_c": 20.0, "condition": "sunny", "solar_irradiance": 293.0, "humidity": 83, "wind_speed": 10.5}, {"hour": 16, "temperature_c": 18.6, "condition": "cloudy", "solar_irradiance": 176.5, "humidity": 75, "wind_speed": 18.4}, {"hour": 17, "temperature_c": 18.9, "condition": "sunny", "solar_irradiance": 47.7, "humidity": 82, "wind_speed": 20.8}, {"hour": 18, "temperature_c": 22.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 82, "wind_speed": 23.2}, {"hour": 19, "temperature_c": 12.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 83, "wind_speed": 19.8}, {"hour": 20, "temperature_c": 13.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 68, "wind_speed": 7.1}, {"hour": 21, "temperature_c": 10.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 85, "wind_speed": 8.6}, {"hour": 22, "temperature_c": 12.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 78, "wind_speed": 18.0}, {"hour": 23, "temperature_c": 11.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 84, "wind_speed": 17.6}]}', name='get_weather_forecast', id='2c056f7d-7343-49e9-9fb0-f5dad3459533', tool_call_id='call_Mlgdhk7KuffdLs7xaJTm4G4d'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_WL2nx9EJhkQo8A8rl0MzHlMu', 'function': {'arguments': '{}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 2854, 'total_tokens': 2867, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1536}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-faa9014c-0321-4ba8-b1ba-437171e4f642-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_WL2nx9EJhkQo8A8rl0MzHlMu', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2854, 'output_tokens': 13, 'total_tokens': 2867}),
#     ToolMessage(content='{"date": "2025-11-09", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1172, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.123, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.11309999999999999, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1235, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1219, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1272, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1875, "period": "peak", "demand_charge": 0.0781}, {"hour": 7, "rate": 0.1717, "period": "peak", "demand_charge": 0.0841}, {"hour": 8, "rate": 0.1745, "period": "peak", "demand_charge": 0.058}, {"hour": 9, "rate": 0.1726, "period": "peak", "demand_charge": 0.0802}, {"hour": 10, "rate": 0.18989999999999999, "period": "peak", "demand_charge": 0.0361}, {"hour": 11, "rate": 0.1765, "period": "peak", "demand_charge": 0.0343}, {"hour": 12, "rate": 0.1783, "period": "peak", "demand_charge": 0.0716}, {"hour": 13, "rate": 0.19, "period": "peak", "demand_charge": 0.0415}, {"hour": 14, "rate": 0.1731, "period": "peak", "demand_charge": 0.0794}, {"hour": 15, "rate": 0.17729999999999999, "period": "peak", "demand_charge": 0.0562}, {"hour": 16, "rate": 0.1731, "period": "peak", "demand_charge": 0.0869}, {"hour": 17, "rate": 0.2301, "period": "peak", "demand_charge": 0.0898}, {"hour": 18, "rate": 0.23679999999999998, "period": "peak", "demand_charge": 0.0806}, {"hour": 19, "rate": 0.2347, "period": "peak", "demand_charge": 0.0861}, {"hour": 20, "rate": 0.2473, "period": "peak", "demand_charge": 0.1164}, {"hour": 21, "rate": 0.17149999999999999, "period": "peak", "demand_charge": 0.026}, {"hour": 22, "rate": 0.1293, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.11689999999999999, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='3a5f372f-b02f-4377-be52-ca9f92c29c44', tool_call_id='call_WL2nx9EJhkQo8A8rl0MzHlMu'),
#     AIMessage(content="Today in San Francisco, the weather is sunny with a current temperature of 18°C (64°F). The forecast shows temperatures ranging from a low of 10.5°C (50.9°F) overnight to a high of 22.6°C (72.7°F) in the afternoon. \n\n### Optimal Thermostat Settings:\n1. **Morning (6 AM - 9 AM)**: Set your thermostat to around **20°C (68°F)**. This will keep your home comfortable as the temperature rises outside.\n2. **Daytime (9 AM - 5 PM)**: Since it's sunny and you may have solar power available, consider setting your thermostat to **22°C (72°F)** during the peak solar hours (10 AM - 4 PM) to maximize comfort while utilizing solar energy.\n3. **Evening (5 PM - 9 PM)**: As temperatures drop, you can lower the thermostat to around **18°C (64°F)** to save energy during the evening hours.\n\n### Energy Cost Considerations:\n- **Peak Hours (12 PM - 6 PM)**: Electricity prices are higher during these hours, so using solar energy during this time is beneficial.\n- **Off-Peak Hours (9 PM - 6 AM)**: Lower your thermostat setting during these hours to save on energy costs.\n\nBy following these recommendations, you can maintain comfort while optimizing energy usage and costs throughout the day.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 290, 'prompt_tokens': 3706, 'total_tokens': 3996, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2816}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'stop', 'logprobs': None}, id='run-dafcbbee-748c-4d6c-a4bc-939306d0246d-0', usage_metadata={'input_tokens': 3706, 'output_tokens': 290, 'total_tokens': 3996})]},
#   'expected_tools': ['get_weather_forecast',
#    'get_electricity_prices',
#    'get_recent_energy_summary'],
#   'expected_response': 'The response should provide temperature recommendations with cost considerations',
#   'timestamp': '2025-11-09T12:54:47.767506'},
#  {'test_id': 'appliance_scheduling_1',
#   'question': 'When should I run my dishwasher and washing machine to save the most money?',
#   'response': {'messages': [SystemMessage(content='You are the EcoHome Energy Advisor, an AI assistant specialized in helping homeowners optimize their energy usage, reduce costs, and maximize the benefits of solar power.\n\nYour primary goals are:\n1. Help users minimize electricity costs by leveraging time-of-use pricing\n2. Maximize the use of solar-generated electricity\n3. Provide actionable recommendations for energy optimization\n4. Calculate potential savings from energy-efficient practices\n\nAvailable Tools:\n- get_weather_forecast: Get weather forecasts including solar irradiance data\n- get_electricity_prices: Get time-of-use electricity pricing by hour\n- query_energy_usage: Query historical energy consumption data\n- query_solar_generation: Query historical solar generation data\n- get_recent_energy_summary: Get summary of recent energy usage and generation\n- search_energy_tips: Search for energy-saving tips and best practices\n- calculate_energy_savings: Calculate potential savings from optimizations. IMPORTANT: When users ask about savings from reducing usage (e.g., "if I reduce X by Y%, how much would I save?"), you MUST:\n  1. First use query_energy_usage to get current usage data for the device/type\n  2. Calculate the optimized usage based on the reduction percentage\n  3. Then use calculate_energy_savings tool with the current usage, optimized usage, and device type\n  4. Present the calculated savings to the user\n\nGuidelines:\n- Always use relevant tools to gather current data before making recommendations\n- Consider weather forecasts when recommending solar-dependent activities\n- Factor in electricity pricing (peak/off-peak) when suggesting optimal times\n- Provide specific time recommendations when relevant\n- Include cost calculations and savings estimates when possible\n- Be clear, concise, and actionable in your responses\n- If you need location information, ask the user or use the context provided\n- Always explain your reasoning behind recommendations\n- When users ask about potential savings from reducing energy usage, you MUST use the calculate_energy_savings tool to provide accurate calculations\n\nWhen making recommendations:\n- Prioritize using solar power when available\n- Suggest off-peak hours for high-energy activities when solar isn\'t available\n- Consider both cost savings and environmental impact\n- Provide specific time windows for optimal actions\n\nFor savings calculations:\n- If a user asks "how much would I save if I reduce [device] usage by X%", you MUST:\n  1. Query current energy usage for that device type\n  2. Calculate the reduced usage (current * (1 - X/100))\n  3. Use calculate_energy_savings tool with these values\n  4. Report the savings including monthly and annual projections\n', id='977bb5e2-684f-498f-8917-aab9cbc9e1b9'),
#     SystemMessage(content='Additional context: Location: San Francisco, CA', id='54d87471-aecb-4c7b-bc99-f5312531ec66'),
#     HumanMessage(content='When should I run my dishwasher and washing machine to save the most money?', id='2ecae284-e728-48ec-b897-f8e2a4904b5d'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_kbkTDGK9pnwgtZD6hnvEFlzS', 'function': {'arguments': '{}', 'name': 'get_electricity_prices'}, 'type': 'function'}, {'id': 'call_13byzGmY28ThoZg0VeEv6xgn', 'function': {'arguments': '{"location": "San Francisco, CA"}', 'name': 'get_weather_forecast'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 49, 'prompt_tokens': 1593, 'total_tokens': 1642, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1536}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-18136c76-42e4-44b9-be10-464e59b6ee86-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_kbkTDGK9pnwgtZD6hnvEFlzS', 'type': 'tool_call'}, {'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA'}, 'id': 'call_13byzGmY28ThoZg0VeEv6xgn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1593, 'output_tokens': 49, 'total_tokens': 1642}),
#     ToolMessage(content='{"date": "2025-11-09", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.12589999999999998, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1211, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.118, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.11399999999999999, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.11299999999999999, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.1263, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1803, "period": "peak", "demand_charge": 0.0643}, {"hour": 7, "rate": 0.1742, "period": "peak", "demand_charge": 0.0727}, {"hour": 8, "rate": 0.1856, "period": "peak", "demand_charge": 0.0639}, {"hour": 9, "rate": 0.18, "period": "peak", "demand_charge": 0.0366}, {"hour": 10, "rate": 0.1746, "period": "peak", "demand_charge": 0.0382}, {"hour": 11, "rate": 0.1814, "period": "peak", "demand_charge": 0.0949}, {"hour": 12, "rate": 0.186, "period": "peak", "demand_charge": 0.0669}, {"hour": 13, "rate": 0.1762, "period": "peak", "demand_charge": 0.0613}, {"hour": 14, "rate": 0.1845, "period": "peak", "demand_charge": 0.0533}, {"hour": 15, "rate": 0.1891, "period": "peak", "demand_charge": 0.0966}, {"hour": 16, "rate": 0.18969999999999998, "period": "peak", "demand_charge": 0.0252}, {"hour": 17, "rate": 0.24259999999999998, "period": "peak", "demand_charge": 0.1383}, {"hour": 18, "rate": 0.23329999999999998, "period": "peak", "demand_charge": 0.1045}, {"hour": 19, "rate": 0.2374, "period": "peak", "demand_charge": 0.0546}, {"hour": 20, "rate": 0.24989999999999998, "period": "peak", "demand_charge": 0.086}, {"hour": 21, "rate": 0.17959999999999998, "period": "peak", "demand_charge": 0.04}, {"hour": 22, "rate": 0.1221, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1183, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='2fa39e6d-248c-4f5e-bbf6-e693572acb59', tool_call_id='call_kbkTDGK9pnwgtZD6hnvEFlzS'),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 3, "current": {"temperature_c": 19, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 19.0}, "hourly": [{"hour": 0, "temperature_c": 13.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 63, "wind_speed": 6.2}, {"hour": 1, "temperature_c": 12.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 50, "wind_speed": 19.0}, {"hour": 2, "temperature_c": 11.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 63, "wind_speed": 9.4}, {"hour": 3, "temperature_c": 11.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 61, "wind_speed": 21.9}, {"hour": 4, "temperature_c": 12.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 60, "wind_speed": 16.3}, {"hour": 5, "temperature_c": 11.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 44, "wind_speed": 21.4}, {"hour": 6, "temperature_c": 16.7, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 60, "wind_speed": 3.0}, {"hour": 7, "temperature_c": 15.6, "condition": "partly_cloudy", "solar_irradiance": 64.74, "humidity": 55, "wind_speed": 6.6}, {"hour": 8, "temperature_c": 19.4, "condition": "partly_cloudy", "solar_irradiance": 49.26, "humidity": 62, "wind_speed": 4.5}, {"hour": 9, "temperature_c": 19.7, "condition": "partly_cloudy", "solar_irradiance": 127.98, "humidity": 56, "wind_speed": 18.4}, {"hour": 10, "temperature_c": 19.5, "condition": "partly_cloudy", "solar_irradiance": 105.11999999999999, "humidity": 52, "wind_speed": 7.8}, {"hour": 11, "temperature_c": 17.2, "condition": "partly_cloudy", "solar_irradiance": 298.91999999999996, "humidity": 45, "wind_speed": 8.7}, {"hour": 12, "temperature_c": 19.1, "condition": "partly_cloudy", "solar_irradiance": 425.16, "humidity": 62, "wind_speed": 20.6}, {"hour": 13, "temperature_c": 19.6, "condition": "partly_cloudy", "solar_irradiance": 320.87999999999994, "humidity": 58, "wind_speed": 24.4}, {"hour": 14, "temperature_c": 21.9, "condition": "partly_cloudy", "solar_irradiance": 148.98, "humidity": 62, "wind_speed": 15.9}, {"hour": 15, "temperature_c": 20.2, "condition": "sunny", "solar_irradiance": 193.01999999999998, "humidity": 54, "wind_speed": 23.7}, {"hour": 16, "temperature_c": 19.5, "condition": "partly_cloudy", "solar_irradiance": 140.04, "humidity": 51, "wind_speed": 6.4}, {"hour": 17, "temperature_c": 23.6, "condition": "partly_cloudy", "solar_irradiance": 31.02, "humidity": 44, "wind_speed": 19.6}, {"hour": 18, "temperature_c": 23.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 50, "wind_speed": 19.8}, {"hour": 19, "temperature_c": 14.3, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 46, "wind_speed": 8.7}, {"hour": 20, "temperature_c": 12.7, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 53, "wind_speed": 18.1}, {"hour": 21, "temperature_c": 11.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 49, "wind_speed": 21.9}, {"hour": 22, "temperature_c": 14.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 57, "wind_speed": 14.3}, {"hour": 23, "temperature_c": 11.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 47, "wind_speed": 14.7}]}', name='get_weather_forecast', id='7d0098f8-c08f-4269-890e-ee0db02c4f78', tool_call_id='call_13byzGmY28ThoZg0VeEv6xgn'),
#     AIMessage(content='To save the most money while running your dishwasher and washing machine in San Francisco, you should consider the following:\n\n### Electricity Pricing\nThe electricity prices for today are as follows (in USD per kWh):\n- **Off-Peak Hours** (Lowest Rates):\n  - 12 AM - 5 AM: $0.1259 to $0.1129\n  - 10 PM - 11 PM: $0.1221 to $0.1183\n- **Peak Hours** (Highest Rates):\n  - 6 AM - 9 PM: $0.1803 to $0.2499\n\n### Recommendations\n1. **Run During Off-Peak Hours**: \n   - **Best Time**: Between 12 AM and 5 AM or after 10 PM.\n   - This is when the rates are the lowest, allowing you to save significantly on your electricity bill.\n\n2. **Consider Solar Generation**:\n   - If you have solar panels, try to run your appliances during the day when solar generation is high (typically between 10 AM and 4 PM). However, since the peak rates are higher during these hours, it may not always be the best option unless you are using excess solar energy.\n\n### Summary\n- **Ideal Time to Run**: Late night (12 AM - 5 AM) or after 10 PM for the best savings.\n- **If Using Solar**: Aim for mid-day when solar generation is at its peak, but be mindful of the higher electricity rates during those hours.\n\nBy following these guidelines, you can optimize your energy usage and reduce your electricity costs effectively!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 335, 'prompt_tokens': 3780, 'total_tokens': 4115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1664}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'stop', 'logprobs': None}, id='run-47886d88-e0af-4e1a-a91d-173660f93802-0', usage_metadata={'input_tokens': 3780, 'output_tokens': 335, 'total_tokens': 4115})]},
#   'expected_tools': ['get_electricity_prices', 'get_weather_forecast'],
#   'expected_response': 'The response should recommend optimal times considering pricing and solar availability',
#   'timestamp': '2025-11-09T12:54:56.792435'},
#  {'test_id': 'solar_maximization_1',
#   'question': 'How can I maximize my use of solar power tomorrow?',
#   'response': {'messages': [SystemMessage(content='You are the EcoHome Energy Advisor, an AI assistant specialized in helping homeowners optimize their energy usage, reduce costs, and maximize the benefits of solar power.\n\nYour primary goals are:\n1. Help users minimize electricity costs by leveraging time-of-use pricing\n2. Maximize the use of solar-generated electricity\n3. Provide actionable recommendations for energy optimization\n4. Calculate potential savings from energy-efficient practices\n\nAvailable Tools:\n- get_weather_forecast: Get weather forecasts including solar irradiance data\n- get_electricity_prices: Get time-of-use electricity pricing by hour\n- query_energy_usage: Query historical energy consumption data\n- query_solar_generation: Query historical solar generation data\n- get_recent_energy_summary: Get summary of recent energy usage and generation\n- search_energy_tips: Search for energy-saving tips and best practices\n- calculate_energy_savings: Calculate potential savings from optimizations. IMPORTANT: When users ask about savings from reducing usage (e.g., "if I reduce X by Y%, how much would I save?"), you MUST:\n  1. First use query_energy_usage to get current usage data for the device/type\n  2. Calculate the optimized usage based on the reduction percentage\n  3. Then use calculate_energy_savings tool with the current usage, optimized usage, and device type\n  4. Present the calculated savings to the user\n\nGuidelines:\n- Always use relevant tools to gather current data before making recommendations\n- Consider weather forecasts when recommending solar-dependent activities\n- Factor in electricity pricing (peak/off-peak) when suggesting optimal times\n- Provide specific time recommendations when relevant\n- Include cost calculations and savings estimates when possible\n- Be clear, concise, and actionable in your responses\n- If you need location information, ask the user or use the context provided\n- Always explain your reasoning behind recommendations\n- When users ask about potential savings from reducing energy usage, you MUST use the calculate_energy_savings tool to provide accurate calculations\n\nWhen making recommendations:\n- Prioritize using solar power when available\n- Suggest off-peak hours for high-energy activities when solar isn\'t available\n- Consider both cost savings and environmental impact\n- Provide specific time windows for optimal actions\n\nFor savings calculations:\n- If a user asks "how much would I save if I reduce [device] usage by X%", you MUST:\n  1. Query current energy usage for that device type\n  2. Calculate the reduced usage (current * (1 - X/100))\n  3. Use calculate_energy_savings tool with these values\n  4. Report the savings including monthly and annual projections\n', id='0d305d39-ae9d-49e1-9bba-b294a7970895'),
#     SystemMessage(content='Additional context: Location: San Francisco, CA', id='c0ab743f-8156-421f-8cdc-573071d8fa6e'),
#     HumanMessage(content='How can I maximize my use of solar power tomorrow?', id='0e1603ed-bb4c-4b1a-a323-a5f1be779608'),
# ...
#     ToolMessage(content='{"start_date": "2023-09-01", "end_date": "2023-09-30", "total_records": 0, "total_generation_kwh": 0, "average_daily_generation": 0.0, "records": []}', name='query_solar_generation', id='bf69957f-7a44-4a8e-b4b7-88e9314a1730', tool_call_id='call_jVbyrEC6TriLGi4RL5F2TdVH'),
#     ToolMessage(content='{"start_date": "2023-09-01", "end_date": "2023-09-30", "device_type": null, "total_records": 0, "total_consumption_kwh": 0, "total_cost_usd": 0, "records": []}', name='query_energy_usage', id='69cd3ae2-5efe-48fb-9425-2a71eb219f45', tool_call_id='call_cN7UnNehXvRfoXvezX3ZV5NN'),
#     AIMessage(content='It appears that there is no recorded solar power generation or energy usage data for the month of September 2023. This could be due to a variety of reasons, such as a lack of solar generation system data or issues with the energy usage tracking.\n\nIf you have a solar power system installed, I recommend checking the inverter or monitoring system for any logs or reports that might provide insights into your solar generation. Additionally, you may want to verify your energy usage data with your utility provider.\n\nIf you have any other questions or need assistance with something else, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 116, 'prompt_tokens': 1802, 'total_tokens': 1918, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1536}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'stop', 'logprobs': None}, id='run-c9d22009-cabb-45cb-8df3-5abe6417c5b3-0', usage_metadata={'input_tokens': 1802, 'output_tokens': 116, 'total_tokens': 1918})]},
#   'expected_tools': ['query_solar_generation', 'query_energy_usage'],
#   'expected_response': 'The response should compare generation vs consumption with analysis',
#   'timestamp': '2025-11-09T12:55:37.209351'},
#  {'test_id': 'comprehensive_optimization_1',
#   'question': 'Give me a comprehensive plan to optimize my energy usage for the next 3 days considering weather and pricing.',
#   'response': {'messages': [SystemMessage(content='You are the EcoHome Energy Advisor, an AI assistant specialized in helping homeowners optimize their energy usage, reduce costs, and maximize the benefits of solar power.\n\nYour primary goals are:\n1. Help users minimize electricity costs by leveraging time-of-use pricing\n2. Maximize the use of solar-generated electricity\n3. Provide actionable recommendations for energy optimization\n4. Calculate potential savings from energy-efficient practices\n\nAvailable Tools:\n- get_weather_forecast: Get weather forecasts including solar irradiance data\n- get_electricity_prices: Get time-of-use electricity pricing by hour\n- query_energy_usage: Query historical energy consumption data\n- query_solar_generation: Query historical solar generation data\n- get_recent_energy_summary: Get summary of recent energy usage and generation\n- search_energy_tips: Search for energy-saving tips and best practices\n- calculate_energy_savings: Calculate potential savings from optimizations. IMPORTANT: When users ask about savings from reducing usage (e.g., "if I reduce X by Y%, how much would I save?"), you MUST:\n  1. First use query_energy_usage to get current usage data for the device/type\n  2. Calculate the optimized usage based on the reduction percentage\n  3. Then use calculate_energy_savings tool with the current usage, optimized usage, and device type\n  4. Present the calculated savings to the user\n\nGuidelines:\n- Always use relevant tools to gather current data before making recommendations\n- Consider weather forecasts when recommending solar-dependent activities\n- Factor in electricity pricing (peak/off-peak) when suggesting optimal times\n- Provide specific time recommendations when relevant\n- Include cost calculations and savings estimates when possible\n- Be clear, concise, and actionable in your responses\n- If you need location information, ask the user or use the context provided\n- Always explain your reasoning behind recommendations\n- When users ask about potential savings from reducing energy usage, you MUST use the calculate_energy_savings tool to provide accurate calculations\n\nWhen making recommendations:\n- Prioritize using solar power when available\n- Suggest off-peak hours for high-energy activities when solar isn\'t available\n- Consider both cost savings and environmental impact\n- Provide specific time windows for optimal actions\n\nFor savings calculations:\n- If a user asks "how much would I save if I reduce [device] usage by X%", you MUST:\n  1. Query current energy usage for that device type\n  2. Calculate the reduced usage (current * (1 - X/100))\n  3. Use calculate_energy_savings tool with these values\n  4. Report the savings including monthly and annual projections\n', id='af4c29bd-55b4-4063-8bb7-1848d2333396'),
#     SystemMessage(content='Additional context: Location: San Francisco, CA', id='0240c36e-ca99-479f-a027-15a54e269767'),
#     HumanMessage(content='Give me a comprehensive plan to optimize my energy usage for the next 3 days considering weather and pricing.', id='fb20d9fe-de2c-43eb-bcdf-7325e4a65f35'),
#     AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_Z2fG1P7eNq7qnglnVjHyzRYJ', 'function': {'arguments': '{"location": "San Francisco, CA", "days": 3}', 'name': 'get_weather_forecast'}, 'type': 'function'}, {'id': 'call_pOjNgsOUIgY5gvmPOW9Oaofq', 'function': {'arguments': '{}', 'name': 'get_electricity_prices'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 1599, 'total_tokens': 1653, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1536}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-b290b39c-bbda-42d2-b93d-221322fc32ec-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 3}, 'id': 'call_Z2fG1P7eNq7qnglnVjHyzRYJ', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {}, 'id': 'call_pOjNgsOUIgY5gvmPOW9Oaofq', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1599, 'output_tokens': 54, 'total_tokens': 1653}),
#     ToolMessage(content='{"location": "San Francisco, CA", "forecast_days": 3, "current": {"temperature_c": 22, "condition": "sunny", "humidity": 50, "wind_speed": 8.0}, "hourly": [{"hour": 0, "temperature_c": 15.7, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 47, "wind_speed": 19.8}, {"hour": 1, "temperature_c": 17.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 58, "wind_speed": 22.4}, {"hour": 2, "temperature_c": 17.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 55, "wind_speed": 11.1}, {"hour": 3, "temperature_c": 15.8, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 43, "wind_speed": 6.4}, {"hour": 4, "temperature_c": 14.5, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 48, "wind_speed": 5.2}, {"hour": 5, "temperature_c": 16.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 40, "wind_speed": 13.8}, {"hour": 6, "temperature_c": 18.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 55, "wind_speed": 10.0}, {"hour": 7, "temperature_c": 21.6, "condition": "sunny", "solar_irradiance": 116.8, "humidity": 54, "wind_speed": 7.1}, {"hour": 8, "temperature_c": 19.0, "condition": "sunny", "solar_irradiance": 127.1, "humidity": 51, "wind_speed": 12.5}, {"hour": 9, "temperature_c": 20.5, "condition": "sunny", "solar_irradiance": 212.3, "humidity": 58, "wind_speed": 7.5}, {"hour": 10, "temperature_c": 23.4, "condition": "cloudy", "solar_irradiance": 186.5, "humidity": 42, "wind_speed": 6.6}, {"hour": 11, "temperature_c": 21.4, "condition": "sunny", "solar_irradiance": 561.1, "humidity": 43, "wind_speed": 16.7}, {"hour": 12, "temperature_c": 23.8, "condition": "sunny", "solar_irradiance": 321.3, "humidity": 58, "wind_speed": 15.8}, {"hour": 13, "temperature_c": 22.8, "condition": "sunny", "solar_irradiance": 368.2, "humidity": 51, "wind_speed": 8.0}, {"hour": 14, "temperature_c": 22.9, "condition": "sunny", "solar_irradiance": 303.7, "humidity": 42, "wind_speed": 17.3}, {"hour": 15, "temperature_c": 24.2, "condition": "sunny", "solar_irradiance": 391.2, "humidity": 50, "wind_speed": 17.0}, {"hour": 16, "temperature_c": 24.0, "condition": "sunny", "solar_irradiance": 105.6, "humidity": 55, "wind_speed": 13.9}, {"hour": 17, "temperature_c": 23.3, "condition": "partly_cloudy", "solar_irradiance": 53.0, "humidity": 41, "wind_speed": 14.0}, {"hour": 18, "temperature_c": 27.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 50, "wind_speed": 19.9}, {"hour": 19, "temperature_c": 15.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 44, "wind_speed": 5.1}, {"hour": 20, "temperature_c": 14.9, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 42, "wind_speed": 3.4}, {"hour": 21, "temperature_c": 17.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 55, "wind_speed": 6.3}, {"hour": 22, "temperature_c": 16.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 47, "wind_speed": 14.1}, {"hour": 23, "temperature_c": 17.3, "condition": "cloudy", "solar_irradiance": 0.0, "humidity": 56, "wind_speed": 5.9}]}', name='get_weather_forecast', id='cde83587-8b4f-4a63-987f-567d4ea2dd56', tool_call_id='call_Z2fG1P7eNq7qnglnVjHyzRYJ'),
#     ToolMessage(content='{"date": "2025-11-09", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kWh", "hourly_rates": [{"hour": 0, "rate": 0.1138, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.1192, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.11199999999999999, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.1215, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.1225, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.11739999999999999, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.1853, "period": "peak", "demand_charge": 0.0972}, {"hour": 7, "rate": 0.186, "period": "peak", "demand_charge": 0.0856}, {"hour": 8, "rate": 0.174, "period": "peak", "demand_charge": 0.0697}, {"hour": 9, "rate": 0.1714, "period": "peak", "demand_charge": 0.0375}, {"hour": 10, "rate": 0.1798, "period": "peak", "demand_charge": 0.0621}, {"hour": 11, "rate": 0.1725, "period": "peak", "demand_charge": 0.0692}, {"hour": 12, "rate": 0.187, "period": "peak", "demand_charge": 0.0234}, {"hour": 13, "rate": 0.1736, "period": "peak", "demand_charge": 0.0853}, {"hour": 14, "rate": 0.1761, "period": "peak", "demand_charge": 0.023}, {"hour": 15, "rate": 0.17679999999999998, "period": "peak", "demand_charge": 0.0437}, {"hour": 16, "rate": 0.1787, "period": "peak", "demand_charge": 0.0948}, {"hour": 17, "rate": 0.23349999999999999, "period": "peak", "demand_charge": 0.0863}, {"hour": 18, "rate": 0.23829999999999998, "period": "peak", "demand_charge": 0.0518}, {"hour": 19, "rate": 0.2413, "period": "peak", "demand_charge": 0.0999}, {"hour": 20, "rate": 0.23049999999999998, "period": "peak", "demand_charge": 0.0654}, {"hour": 21, "rate": 0.17859999999999998, "period": "peak", "demand_charge": 0.0536}, {"hour": 22, "rate": 0.11349999999999999, "period": "off_peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.1249, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='2082f65b-693f-421e-9d6f-b18156a41f1d', tool_call_id='call_pOjNgsOUIgY5gvmPOW9Oaofq'),
#     AIMessage(content="Here's a comprehensive energy optimization plan for the next three days in San Francisco, CA, considering the weather forecast and time-of-use electricity pricing.\n\n### Weather Forecast Overview\n- **Day 1 (Today)**: Sunny with high temperatures around 24°C (75°F). Good solar generation expected.\n- **Day 2**: Similar sunny conditions with temperatures reaching up to 27°C (81°F). Excellent solar generation.\n- **Day 3**: Partly cloudy with temperatures around 23°C (73°F). Solar generation may be slightly reduced.\n\n### Electricity Pricing Overview\n- **Peak Hours**: 6 AM - 8 PM (Rates range from $0.1714 to $0.2413 per kWh)\n- **Off-Peak Hours**: 12 AM - 6 AM and 8 PM - 12 AM (Rates range from $0.1119 to $0.1249 per kWh)\n\n### Optimization Plan\n\n#### Day 1 (Today)\n- **Morning (6 AM - 9 AM)**: \n  - **Action**: Run high-energy appliances (e.g., dishwasher, laundry) during off-peak hours (12 AM - 6 AM) if possible. \n  - **Solar Generation**: Start using solar power from 7 AM when irradiance begins to rise.\n  \n- **Midday (10 AM - 2 PM)**:\n  - **Action**: Maximize solar usage by running energy-intensive devices (e.g., HVAC, pool pump) during peak solar hours (10 AM - 2 PM).\n  - **Tip**: Set your thermostat to a higher temperature to reduce HVAC load.\n\n- **Afternoon (3 PM - 6 PM)**:\n  - **Action**: Continue using solar power for any remaining high-energy tasks. \n  - **Tip**: Avoid using heavy appliances during peak pricing hours (3 PM - 8 PM).\n\n- **Evening (6 PM - 12 AM)**:\n  - **Action**: Shift to off-peak usage after 8 PM for any remaining energy needs.\n\n#### Day 2\n- **Morning (6 AM - 9 AM)**:\n  - **Action**: Similar to Day 1, run appliances during off-peak hours if possible.\n\n- **Midday (10 AM - 2 PM)**:\n  - **Action**: Utilize solar power for all high-energy tasks. Consider running the dishwasher or laundry during this time.\n\n- **Afternoon (3 PM - 6 PM)**:\n  - **Action**: Limit energy usage during peak pricing hours. Use solar power as much as possible.\n\n- **Evening (6 PM - 12 AM)**:\n  - **Action**: Use off-peak rates for any remaining energy needs.\n\n#### Day 3\n- **Morning (6 AM - 9 AM)**:\n  - **Action**: Continue to run appliances during off-peak hours.\n\n- **Midday (10 AM - 2 PM)**:\n  - **Action**: Use solar power for energy-intensive tasks. Expect slightly reduced solar generation due to partly cloudy conditions.\n\n- **Afternoon (3 PM - 6 PM)**:\n  - **Action**: Limit energy usage during peak pricing hours.\n\n- **Evening (6 PM - 12 AM)**:\n  - **Action**: Use off-peak rates for any remaining energy needs.\n\n### Additional Recommendations\n- **Monitor Solar Generation**: Keep an eye on solar generation data to adjust your usage accordingly.\n- **Energy-Efficient Practices**: Consider implementing energy-saving tips such as using LED bulbs, unplugging devices when not in use, and optimizing HVAC settings.\n\nBy following this plan, you can maximize your solar energy usage, minimize electricity costs, and contribute to a more sustainable energy future. If you have specific devices or appliances in mind, let me know, and I can provide tailored recommendations for those as well!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 807, 'prompt_tokens': 3732, 'total_tokens': 4539, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1536}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'finish_reason': 'stop', 'logprobs': None}, id='run-3e88e2f4-a006-4779-93ef-a7a930138024-0', usage_metadata={'input_tokens': 3732, 'output_tokens': 807, 'total_tokens': 4539})]},
#   'expected_tools': ['get_weather_forecast',
#    'get_electricity_prices',
#    'get_recent_energy_summary',
#    'search_energy_tips'],
#   'expected_response': 'The response should provide a detailed multi-day optimization plan',
#   'timestamp': '2025-11-09T12:55:59.355484'}]

# %% [markdown]
# ## 4. Evaluate Responses

# %%
# TODO: Implement evaluation functions
# Create functions to evaluate:
# - Final Response
# - Tool usage

def extract_tools_used(messages):
    """Extract list of tools used from agent messages"""
    from langchain_core.messages import AIMessage, ToolMessage
    tools_used = []
    for msg in messages:
        # Check if it's an AIMessage with tool calls
        if isinstance(msg, AIMessage) and hasattr(msg, 'tool_calls') and msg.tool_calls:
            for tool_call in msg.tool_calls:
                tool_name = tool_call.get("name", "")
                if tool_name and tool_name not in tools_used:
                    tools_used.append(tool_name)
    return tools_used

# %%
# TODO: Create a response evaluator
def evaluate_response(question, final_response, expected_response):
    """Evaluate a single response against expected response"""
    if isinstance(final_response, str) and final_response.startswith("Error:"):
        return {
            "score": 0,
            "accuracy": 0,
            "relevance": 0,
            "completeness": 0,
            "reasoning": 0,
            "feedback": "Error occurred during execution"
        }
    
    # Extract the final message content
    if isinstance(final_response, dict) and "messages" in final_response:
        messages = final_response["messages"]
        if messages:
            content = messages[-1].content if hasattr(messages[-1], 'content') else str(messages[-1])
        else:
            content = ""
    else:
        content = str(final_response)
    
    content_lower = content.lower()
    expected_lower = expected_response.lower()
    
    # Check for key terms in expected response
    expected_keywords = []
    if "time" in expected_lower or "hour" in expected_lower:
        expected_keywords.append("time")
    if "cost" in expected_lower or "price" in expected_lower or "saving" in expected_lower:
        expected_keywords.append("cost")
    if "solar" in expected_lower:
        expected_keywords.append("solar")
    if "recommend" in expected_lower or "suggest" in expected_lower:
        expected_keywords.append("recommendation")
    if "analysis" in expected_lower or "breakdown" in expected_lower:
        expected_keywords.append("analysis")
    
    # Score based on keyword presence
    keyword_score = 0
    for keyword in expected_keywords:
        if keyword in content_lower:
            keyword_score += 1
    
    keyword_accuracy = keyword_score / len(expected_keywords) if expected_keywords else 0.5
    
    # Relevance: Check if response addresses the question
    question_keywords = set(question.lower().split())
    response_keywords = set(content_lower.split())
    relevance = len(question_keywords.intersection(response_keywords)) / len(question_keywords) if question_keywords else 0.5
    relevance = min(1.0, relevance * 2)  # Scale up
    
    # Completeness: Check response length and structure
    word_count = len(content.split())
    completeness = min(1.0, word_count / 50)  # Expect at least 50 words for completeness
    
    # Reasoning: Check for explanation words
    reasoning_words = ["because", "since", "due to", "considering", "based on", "therefore", "as a result"]
    has_reasoning = any(word in content_lower for word in reasoning_words)
    reasoning = 0.8 if has_reasoning else 0.4
    
    # Overall score (weighted average)
    accuracy = keyword_accuracy
    overall_score = (accuracy * 0.3 + relevance * 0.3 + completeness * 0.2 + reasoning * 0.2)
    
    feedback = []
    if accuracy < 0.7:
        feedback.append("Missing some expected information")
    if relevance < 0.6:
        feedback.append("Response may not fully address the question")
    if completeness < 0.6:
        feedback.append("Response could be more comprehensive")
    if reasoning < 0.6:
        feedback.append("Response lacks clear reasoning")
    
    return {
        "score": round(overall_score, 2),
        "accuracy": round(accuracy, 2),
        "relevance": round(relevance, 2),
        "completeness": round(completeness, 2),
        "reasoning": round(reasoning, 2),
        "feedback": "; ".join(feedback) if feedback else "Good response"
    }

# %%
# TODO: Create a tool udage evaluator
def evaluate_tool_usage(messages, expected_tools):
    """Evaluate if the right tools were used"""
    if isinstance(messages, dict) and "messages" in messages:
        messages = messages["messages"]
    
    tools_used = extract_tools_used(messages)
    
    if not expected_tools:
        return {
            "score": 1.0,
            "tools_used": tools_used,
            "expected_tools": expected_tools,
            "missing_tools": [],
            "unexpected_tools": [],
            "feedback": "No specific tools expected"
        }
    
    # Check which expected tools were used
    missing_tools = [tool for tool in expected_tools if tool not in tools_used]
    unexpected_tools = [tool for tool in tools_used if tool not in expected_tools]
    
    # Calculate score
    if not expected_tools:
        score = 1.0
    else:
        used_expected = len(expected_tools) - len(missing_tools)
        score = used_expected / len(expected_tools)
    
    # Generate feedback
    feedback_parts = []
    if missing_tools:
        feedback_parts.append(f"Missing tools: {', '.join(missing_tools)}")
    if unexpected_tools:
        feedback_parts.append(f"Unexpected tools used: {', '.join(unexpected_tools)}")
    if not missing_tools and not unexpected_tools:
        feedback_parts.append("All expected tools were used correctly")
    
    return {
        "score": round(score, 2),
        "tools_used": tools_used,
        "expected_tools": expected_tools,
        "missing_tools": missing_tools,
        "unexpected_tools": unexpected_tools,
        "feedback": "; ".join(feedback_parts)
    }

# %%
# TODO: Generate a comprehensive evaluation report
# Calculate overall scores and metrics
# Identify strengths and weaknesses
# Provide recommendations for improvement
def generate_evaluation_report(test_results):
    """Generate a comprehensive evaluation report from test results"""
    
    if not test_results:
        return "No test results to evaluate"
    
    # Evaluate each test result
    evaluations = []
    for result in test_results:
        if isinstance(result.get('response'), str) and result['response'].startswith("Error:"):
            eval_result = {
                'test_id': result['test_id'],
                'response_eval': {"score": 0, "feedback": "Error occurred"},
                'tool_eval': {"score": 0, "feedback": "Error occurred"},
                'overall_score': 0
            }
        else:
            # Evaluate response
            response_eval = evaluate_response(
                result['question'],
                result['response'],
                result.get('expected_response', '')
            )
            
            # Evaluate tool usage
            tool_eval = evaluate_tool_usage(
                result['response'],
                result.get('expected_tools', [])
            )
            
            # Overall score (weighted: 60% response, 40% tools)
            overall_score = (response_eval['score'] * 0.6 + tool_eval['score'] * 0.4)
            
            eval_result = {
                'test_id': result['test_id'],
                'question': result['question'],
                'response_eval': response_eval,
                'tool_eval': tool_eval,
                'overall_score': round(overall_score, 2)
            }
        
        evaluations.append(eval_result)
    
    # Calculate aggregate metrics
    total_tests = len(evaluations)
    successful_tests = sum(1 for e in evaluations if e['overall_score'] > 0)
    
    avg_overall = sum(e['overall_score'] for e in evaluations) / total_tests if total_tests > 0 else 0
    avg_response = sum(e['response_eval']['score'] for e in evaluations) / total_tests if total_tests > 0 else 0
    avg_tool = sum(e['tool_eval']['score'] for e in evaluations) / total_tests if total_tests > 0 else 0
    
    # Calculate average sub-scores
    avg_accuracy = sum(e['response_eval'].get('accuracy', 0) for e in evaluations) / total_tests if total_tests > 0 else 0
    avg_relevance = sum(e['response_eval'].get('relevance', 0) for e in evaluations) / total_tests if total_tests > 0 else 0
    avg_completeness = sum(e['response_eval'].get('completeness', 0) for e in evaluations) / total_tests if total_tests > 0 else 0
    avg_reasoning = sum(e['response_eval'].get('reasoning', 0) for e in evaluations) / total_tests if total_tests > 0 else 0
    
    # Identify strengths and weaknesses
    high_scores = [e for e in evaluations if e['overall_score'] >= 0.8]
    low_scores = [e for e in evaluations if e['overall_score'] < 0.6]
    
    # Tool usage analysis
    all_tools_used = []
    for e in evaluations:
        all_tools_used.extend(e['tool_eval'].get('tools_used', []))
    tool_frequency = {}
    for tool in all_tools_used:
        tool_frequency[tool] = tool_frequency.get(tool, 0) + 1
    
    # Generate report
    report = []
    report.append("=" * 80)
    report.append("ECOHOME ENERGY ADVISOR - EVALUATION REPORT")
    report.append("=" * 80)
    report.append("")
    report.append(f"Total Tests: {total_tests}")
    report.append(f"Successful Tests: {successful_tests} ({successful_tests/total_tests*100:.1f}%)")
    report.append("")
    report.append("OVERALL METRICS")
    report.append("-" * 80)
    report.append(f"Average Overall Score: {avg_overall:.2f}/1.00")
    report.append(f"Average Response Score: {avg_response:.2f}/1.00")
    report.append(f"Average Tool Usage Score: {avg_tool:.2f}/1.00")
    report.append("")
    report.append("RESPONSE QUALITY BREAKDOWN")
    report.append("-" * 80)
    report.append(f"Average Accuracy: {avg_accuracy:.2f}/1.00")
    report.append(f"Average Relevance: {avg_relevance:.2f}/1.00")
    report.append(f"Average Completeness: {avg_completeness:.2f}/1.00")
    report.append(f"Average Reasoning: {avg_reasoning:.2f}/1.00")
    report.append("")
    
    if high_scores:
        report.append("STRENGTHS (Tests with score >= 0.8)")
        report.append("-" * 80)
        for e in high_scores[:5]:  # Top 5
            report.append(f"  • {e['test_id']}: {e['overall_score']:.2f}")
        report.append("")
    
    if low_scores:
        report.append("AREAS FOR IMPROVEMENT (Tests with score < 0.6)")
        report.append("-" * 80)
        for e in low_scores[:5]:  # Top 5
            report.append(f"  • {e['test_id']}: {e['overall_score']:.2f}")
            report.append(f"    Response: {e['response_eval'].get('feedback', 'N/A')}")
            report.append(f"    Tools: {e['tool_eval'].get('feedback', 'N/A')}")
        report.append("")
    
    if tool_frequency:
        report.append("TOOL USAGE FREQUENCY")
        report.append("-" * 80)
        sorted_tools = sorted(tool_frequency.items(), key=lambda x: x[1], reverse=True)
        for tool, count in sorted_tools:
            report.append(f"  • {tool}: {count} times")
        report.append("")
    
    report.append("DETAILED TEST RESULTS")
    report.append("-" * 80)
    for e in evaluations:
        report.append(f"\nTest: {e['test_id']}")
        report.append(f"  Question: {e.get('question', 'N/A')[:60]}...")
        report.append(f"  Overall Score: {e['overall_score']:.2f}/1.00")
        report.append(f"  Response Score: {e['response_eval']['score']:.2f}/1.00")
        report.append(f"    - {e['response_eval'].get('feedback', 'N/A')}")
        report.append(f"  Tool Usage Score: {e['tool_eval']['score']:.2f}/1.00")
        report.append(f"    - Used: {', '.join(e['tool_eval'].get('tools_used', []))}")
        report.append(f"    - Expected: {', '.join(e['tool_eval'].get('expected_tools', []))}")
        report.append(f"    - {e['tool_eval'].get('feedback', 'N/A')}")
    
    report.append("")
    report.append("=" * 80)
    report.append("RECOMMENDATIONS")
    report.append("=" * 80)
    
    recommendations = []
    if avg_accuracy < 0.7:
        recommendations.append("Improve accuracy by ensuring all expected information is included in responses")
    if avg_relevance < 0.7:
        recommendations.append("Enhance relevance by better understanding user questions and context")
    if avg_completeness < 0.7:
        recommendations.append("Increase completeness by providing more detailed and comprehensive answers")
    if avg_reasoning < 0.7:
        recommendations.append("Strengthen reasoning by explaining the 'why' behind recommendations")
    if avg_tool < 0.7:
        recommendations.append("Improve tool usage by ensuring all relevant tools are called when needed")
    if not recommendations:
        recommendations.append("Agent is performing well! Continue monitoring and fine-tuning.")
    
    for i, rec in enumerate(recommendations, 1):
        report.append(f"{i}. {rec}")
    
    report.append("")
    report.append("=" * 80)
    
    return "\n".join(report)

# %%
# Run evaluation on test results
if 'test_results' in locals() and test_results:
    print("Generating evaluation report...")
    report = generate_evaluation_report(test_results)
    print(report)
else:
    print("No test results available. Please run the agent tests first.")
# Out:
# Generating evaluation report...
# ================================================================================
# ECOHOME ENERGY ADVISOR - EVALUATION REPORT
# ================================================================================
#
# Total Tests: 10
# Successful Tests: 10 (100.0%)
#
# OVERALL METRICS
# --------------------------------------------------------------------------------
# Average Overall Score: 0.79/1.00
# Average Response Score: 0.82/1.00
# Average Tool Usage Score: 0.73/1.00
#
# RESPONSE QUALITY BREAKDOWN
# --------------------------------------------------------------------------------
# Average Accuracy: 0.66/1.00
# Average Relevance: 0.94/1.00
# Average Completeness: 1.00/1.00
# Average Reasoning: 0.72/1.00
#
# STRENGTHS (Tests with score >= 0.8)
# --------------------------------------------------------------------------------
#   • ev_charging_1: 0.89
#   • thermostat_1: 0.84
#   • appliance_scheduling_1: 0.98
#   • solar_maximization_1: 0.84
#   • cost_analysis_1: 0.81
#
# AREAS FOR IMPROVEMENT (Tests with score < 0.6)
# --------------------------------------------------------------------------------
#   • savings_calculation_1: 0.56
#     Response: Missing some expected information
#     Tools: Missing tools: calculate_energy_savings
#
# TOOL USAGE FREQUENCY
# --------------------------------------------------------------------------------
#   • get_electricity_prices: 6 times
#   • get_weather_forecast: 5 times
#   • query_energy_usage: 3 times
#   • get_recent_energy_summary: 1 times
#   • search_energy_tips: 1 times
#   • query_solar_generation: 1 times
#
# DETAILED TEST RESULTS
# --------------------------------------------------------------------------------
#
# Test: ev_charging_1
#   Question: When should I charge my electric car tomorrow to minimize co...
#   Overall Score: 0.89/1.00
#   Response Score: 0.82/1.00
#     - Response lacks clear reasoning
#   Tool Usage Score: 1.00/1.00
#     - Used: get_weather_forecast, get_electricity_prices
#     - Expected: get_weather_forecast, get_electricity_prices
#     - All expected tools were used correctly
#
# Test: ev_charging_2
#   Question: I need to charge my EV from 20% to 80% battery. When is the ...
#   Overall Score: 0.73/1.00
#   Response Score: 0.88/1.00
#     - Good response
#   Tool Usage Score: 0.50/1.00
#     - Used: get_electricity_prices
#     - Expected: get_electricity_prices, get_weather_forecast
#     - Missing tools: get_weather_forecast
#
# Test: thermostat_1
#   Question: What's the optimal thermostat setting for today to balance c...
#   Overall Score: 0.84/1.00
#   Response Score: 0.96/1.00
#     - Good response
#   Tool Usage Score: 0.67/1.00
#     - Used: get_weather_forecast, get_electricity_prices
#     - Expected: get_weather_forecast, get_electricity_prices, get_recent_energy_summary
#     - Missing tools: get_recent_energy_summary
#
# Test: appliance_scheduling_1
#   Question: When should I run my dishwasher and washing machine to save ...
#   Overall Score: 0.98/1.00
#   Response Score: 0.96/1.00
#     - Good response
#   Tool Usage Score: 1.00/1.00
#     - Used: get_electricity_prices, get_weather_forecast
#     - Expected: get_electricity_prices, get_weather_forecast
#     - All expected tools were used correctly
#
# Test: solar_maximization_1
#   Question: How can I maximize my use of solar power tomorrow?...
#   Overall Score: 0.84/1.00
#   Response Score: 0.96/1.00
#     - Good response
#   Tool Usage Score: 0.67/1.00
#     - Used: get_weather_forecast, get_electricity_prices
#     - Expected: get_weather_forecast, query_solar_generation, get_electricity_prices
#     - Missing tools: query_solar_generation
#
# Test: cost_analysis_1
#   Question: How much did I spend on electricity last week and what was m...
#   Overall Score: 0.81/1.00
#   Response Score: 0.69/1.00
#     - Missing some expected information; Response lacks clear reasoning
#   Tool Usage Score: 1.00/1.00
#     - Used: query_energy_usage, get_recent_energy_summary
#     - Expected: query_energy_usage, get_recent_energy_summary
#     - All expected tools were used correctly
#
# Test: energy_tips_1
#   Question: What are the best ways to reduce my HVAC energy consumption?...
#   Overall Score: 0.78/1.00
#   Response Score: 0.96/1.00
#     - Good response
#   Tool Usage Score: 0.50/1.00
#     - Used: search_energy_tips
#     - Expected: search_energy_tips, query_energy_usage
#     - Missing tools: query_energy_usage
#
# Test: savings_calculation_1
#   Question: If I reduce my air conditioning usage by 30%, how much money...
#   Overall Score: 0.56/1.00
#   Response Score: 0.60/1.00
#     - Missing some expected information
#   Tool Usage Score: 0.50/1.00
#     - Used: query_energy_usage
#     - Expected: query_energy_usage, calculate_energy_savings
#     - Missing tools: calculate_energy_savings
#
# Test: solar_generation_1
#   Question: How much solar power did I generate last month and how does ...
#   Overall Score: 0.75/1.00
#   Response Score: 0.58/1.00
#     - Missing some expected information
#   Tool Usage Score: 1.00/1.00
#     - Used: query_solar_generation, query_energy_usage
#     - Expected: query_solar_generation, query_energy_usage
#     - All expected tools were used correctly
#
# Test: comprehensive_optimization_1
#   Question: Give me a comprehensive plan to optimize my energy usage for...
#   Overall Score: 0.69/1.00
#   Response Score: 0.81/1.00
#     - Missing some expected information
#   Tool Usage Score: 0.50/1.00
#     - Used: get_weather_forecast, get_electricity_prices
#     - Expected: get_weather_forecast, get_electricity_prices, get_recent_energy_summary, search_energy_tips
#     - Missing tools: get_recent_energy_summary, search_energy_tips
#
# ================================================================================
# RECOMMENDATIONS
# ================================================================================
# 1. Improve accuracy by ensuring all expected information is included in responses
#
# ================================================================================
