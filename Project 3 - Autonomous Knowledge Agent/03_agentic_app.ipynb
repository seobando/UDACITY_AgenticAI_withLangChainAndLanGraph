# %% [markdown]
# ## Setup

# %%
from dotenv import load_dotenv
import importlib
import utils
importlib.reload(utils)  # Reload to pick up any changes
from utils import send_message, chat_interface

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Run

# %%
# TODO: Develop your agents under `agentic/agents`
# TODO: Develop your tools under `agentic/tools`
# TODO: Modify `agentic/workflow` in order to orchestrate your agents

# %%
# IDEALLY YOUR ONLY IMPORT HERE IS:
from agentic.workflow import orchestrator

# Reload the workflow module to pick up any changes
#import importlib
#import agentic.workflow
#importlib.reload(agentic.workflow)
#rom agentic.workflow import orchestrator

# %%
# Jupyter-friendly way to interact with the agent
# Use send_message() to send individual messages (works better in notebooks)

# Example 1: Send a message
# Note: user_id should match a user from cultpass_users.jsonl (e.g., "a4ab87", "f556c0", etc.)
send_message(
    orchestrator, 
    "I can't log in to my CultPass account", 
    ticket_id="1",
    user_id="a4ab87",  # Alice Kingsley
    account_id="cultpass"
)
# Out:
# 2025-11-10 11:22:18,954 - udahub - INFO - Processing user message
# 2025-11-10 11:22:18,959 - udahub - INFO - Supervisor node called
# 2025-11-10 11:22:18,960 - udahub - INFO - Supervisor routing decision
# 2025-11-10 11:22:18,980 - udahub - INFO - Conversation saved to database
# 2025-11-10 11:22:18,981 - udahub - INFO - Response generated
# User: I can't log in to my CultPass account
#
# Assistant: Subject: Escalation of Login Issue - Ticket Reference: [Insert Ticket Number]
#
# Dear [Customer's Name],
#
# Thank you for reaching out to us regarding your login issue with your CultPass account. I understand how frustrating it can be to encounter difficulties accessing your account, and I appreciate your patience as we work to resolve this matter.
#
# ...

# %%
# Example 2: Continue the conversation (same ticket_id maintains context)
send_message(orchestrator, "How do I reset my password?", ticket_id="1", user_id="a4ab87")
# Out:
# 2025-11-10 11:22:18,992 - udahub - INFO - Processing user message
# 2025-11-10 11:22:18,996 - udahub - INFO - Supervisor node called
# 2025-11-10 11:22:18,996 - udahub - INFO - Supervisor routing decision
# 2025-11-10 11:22:19,012 - udahub - INFO - Conversation saved to database
# 2025-11-10 11:22:19,014 - udahub - INFO - Response generated
# User: How do I reset my password?
#
# Assistant: Subject: Escalation of Login Issue - Ticket Reference: [Insert Ticket Number]
#
# Dear [Customer's Name],
#
# Thank you for reaching out to us regarding your login issue with your CultPass account. I understand how frustrating it can be to encounter difficulties accessing your account, and I appreciate your patience as we work to resolve this matter.
#
# ...

# %%
# Example 3: Start a new conversation (use a different ticket_id)
send_message(orchestrator, "What's included in my subscription?", ticket_id="2", user_id="f556c0")
# Out:
# 2025-11-10 11:22:19,023 - udahub - INFO - Processing user message
# 2025-11-10 11:22:19,026 - udahub - INFO - Supervisor node called
# 2025-11-10 11:22:19,027 - udahub - INFO - Supervisor routing decision
# 2025-11-10 11:22:19,041 - udahub - INFO - Conversation saved to database
# 2025-11-10 11:22:19,042 - udahub - INFO - Response generated
# User: What's included in my subscription?
#
# Assistant: Subject: Escalation of Subscription Inquiry - Ticket Reference #123456
#
# Dear Customer,
#
# Thank you for reaching out to us regarding your subscription inquiry. I understand that you were unable to find the relevant information in our knowledge base, and I appreciate your patience as we work to resolve this matter.
#
# To summarize, you are seeking details about your subscription, and it appears that the information you need is not readily available in our resources. I will escalate this issue to a human support agent who will be able to assist you further.
#
# ...

# %% [markdown]
# ### Demonstration 1: KB-Grounded Response (Success)
#
# This demonstrates a successful knowledge base retrieval and response.

# %%
# KB Success: Question that should find relevant article about subscription status/quota
# This should match articles with keywords: subscription, quota, status, check
send_message(
    orchestrator,
    "How do I check my subscription status and quota?",
    ticket_id="kb-success-1",
    user_id="f556c0",  # Bob Stone
    account_id="cultpass"
)
# Out:
# 2025-11-10 11:22:19,051 - udahub - INFO - Processing user message
# 2025-11-10 11:22:19,055 - udahub - INFO - Supervisor node called
# 2025-11-10 11:22:19,056 - udahub - INFO - Supervisor routing decision
# 2025-11-10 11:22:19,071 - udahub - INFO - Conversation saved to database
# 2025-11-10 11:22:19,072 - udahub - INFO - Response generated
# User: How do I check my subscription status and quota?
#
# Assistant: Subject: Escalation of Subscription Inquiry - Ticket Reference: [Insert Ticket Number]
#
# Dear Customer,
#
# Thank you for reaching out to us regarding your subscription inquiry. I understand that you are having difficulty finding information on how to check your subscription quota.
#
# To summarize your issue: You are seeking guidance on how to access and review your subscription quota, but the information available in our knowledge base did not meet your needs.
#
# ...

# %% [markdown]
# ### Demonstration 2: Database Tool Usage
#
# This demonstrates structured database tool outputs and how they're used in responses.

# %%
# Test DB tool usage - subscription lookup
# This should: 1) Try KB first (may or may not find), 2) Use lookup_subscription tool, 3) Return structured subscription info
send_message(
    orchestrator,
    "Can you tell me my subscription details? My user ID is f556c0",
    ticket_id="db-tool-1",
    user_id="f556c0",  # Bob Stone
    account_id="cultpass"
)
# Out:
# 2025-11-10 11:22:19,081 - udahub - INFO - Processing user message
# 2025-11-10 11:22:19,084 - udahub - INFO - Supervisor node called
# 2025-11-10 11:22:19,085 - udahub - INFO - Supervisor routing decision
# 2025-11-10 11:22:19,104 - udahub - INFO - Conversation saved to database
# 2025-11-10 11:22:19,105 - udahub - INFO - Response generated
# User: Can you tell me my subscription details? My user ID is f556c0
#
# Assistant: Subject: Escalation of Subscription Inquiry - Ticket Reference #123456
#
# Dear Customer,
#
# Thank you for reaching out to us regarding your subscription status. I understand that you were unable to find the relevant information in our knowledge base and are seeking assistance with your inquiry.
#
# To summarize, you are inquiring about the status of your subscription using your user ID. Since this issue requires human intervention, I have escalated your ticket to a support agent who will be able to assist you further.
#
# ...

# %% [markdown]
# ### Demonstration 3: KB Miss → Escalation
#
# This demonstrates escalation when no relevant knowledge base article is found.

# %%
# KB Miss: Question that won't find relevant article (should escalate)
send_message(
    orchestrator,
    "I want to change my account to a different email domain that's not supported",
    ticket_id="kb-miss-1",
    user_id="a4ab87",  # Alice Kingsley
    account_id="cultpass"
)
# Out:
# 2025-11-10 11:22:19,117 - udahub - INFO - Processing user message
# 2025-11-10 11:22:19,122 - udahub - INFO - Supervisor node called
# 2025-11-10 11:22:19,124 - udahub - INFO - Supervisor routing decision
# 2025-11-10 11:22:19,137 - udahub - INFO - Conversation saved to database
# 2025-11-10 11:22:19,138 - udahub - INFO - Response generated
# User: I want to change my account to a different email domain that's not supported
#
# Assistant: Subject: Escalation of Account Email Change Request
#
# Dear Customer,
#
# Thank you for reaching out to us. I understand that you are looking to change your account email to a domain that is currently not supported by our system.
#
# I want to assure you that I have escalated your request to a human support agent who will be able to assist you further with this matter. Your ticket reference is [#123456].
#
# ...

# %% [markdown]
# ### Demonstration 4: Memory Retrieval and Personalization
#
# This demonstrates long-term memory retrieval and how historical context is used.

# %%
# Import memory functions
from agentic.memory import get_conversation_history, get_user_preferences, get_historical_context

# Get conversation history for a user
print("=== Conversation History ===")
history = get_conversation_history(user_id="a4ab87", limit=5)
for ticket in history:
    print(f"\nTicket ID: {ticket['ticket_id']}")
    print(f"Status: {ticket['status']}")
    print(f"Issue Type: {ticket.get('issue_type', 'N/A')}")
    print(f"Messages: {len(ticket['messages'])}")
    if ticket['messages']:
        print(f"  First message: {ticket['messages'][0]['content'][:50]}...")

print("\n=== User Preferences ===")
prefs = get_user_preferences(user_id="a4ab87")
print(f"Resolved Issues: {len(prefs['resolved_issues'])}")
print(f"Common Issues: {prefs['common_issues']}")

print("\n=== Historical Context for Login Issue ===")
context = get_historical_context(user_id="a4ab87", current_issue_type="login")
print(context if context else "No historical context available")

# Now test with a new login question to see personalization
print("\n=== Testing Personalization ===")
send_message(
    orchestrator,
    "I'm having login issues again",
    ticket_id="memory-test-1",
    user_id="a4ab87",  # Same user - should use historical context
    account_id="cultpass"
)
# Out:
# === Conversation History ===
#
# Ticket ID: 3
# Status: open
# Issue Type: other
# Messages: 3
#   First message: I need to speak to a human agent...
#
# Ticket ID: memory-test-1
# Status: open
# Issue Type: login
# Messages: 3
#   First message: I'm having login issues again...
#
# Ticket ID: kb-miss-1
# Status: escalated
# Issue Type: other
# Messages: 3
#   First message: I want to change my account to a different email d...
#
# Ticket ID: 1
# Status: escalated
# Issue Type: login
# Messages: 4
#   First message: I can't log in to my CultPass account...
#
# Ticket ID: 8561bcaf-6dbc-400b-aec4-433dfd38ee43
# Status: open
# Issue Type: None
# Messages: 1
#   First message: I can't log in to my Cultpass account....
#
# === User Preferences ===
# Resolved Issues: 0
# Common Issues: {'other': 2, 'login': 2}
#
# === Historical Context for Login Issue ===
# 2025-11-10 11:22:19,196 - udahub - INFO - Processing user message
# 2025-11-10 11:22:19,198 - udahub - INFO - Supervisor node called
# ...

# %% [markdown]
# ### Demonstration 5: Logging and Observability
#
# This demonstrates structured logging with routing decisions, classifications, tool usage, and outcomes.

# %%
import json
import os
from pathlib import Path
from datetime import datetime

# Find the most recent log file
log_dir = Path("logs")
if log_dir.exists():
    log_files = sorted(log_dir.glob("udahub_*.jsonl"), key=os.path.getmtime, reverse=True)
    
    if log_files:
        latest_log = log_files[0]
        print(f"Reading logs from: {latest_log}\n")
        print("=" * 80)
        
        # Read and display sample log entries
        with open(latest_log, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            
        print(f"Total log entries: {len(lines)}\n")
        print("Sample log entries showing key events:\n")
        print("-" * 80)
        
        # Show different types of log entries
        shown_types = set()
        for line in lines[-50:]:  # Last 50 entries
            try:
                log_entry = json.loads(line)
                log_type = log_entry.get("message", "")
                
                # Show one of each important type
                if "Supervisor routing decision" in log_type and "routing_decision" not in shown_types:
                    print("📊 SUPERVISOR ROUTING DECISION:")
                    print(json.dumps(log_entry, indent=2))
                    print("-" * 80)
                    shown_types.add("routing_decision")
                
                elif "Ticket classified successfully" in log_type and "classification" not in shown_types:
                    print("🏷️  CLASSIFICATION:")
                    print(json.dumps(log_entry, indent=2))
                    print("-" * 80)
                    shown_types.add("classification")
                
                elif "Tool invoked" in log_type and "tool_invoke" not in shown_types:
                    print("🔧 TOOL INVOCATION:")
                    print(json.dumps(log_entry, indent=2))
                    print("-" * 80)
                    shown_types.add("tool_invoke")
                
                elif "KB search completed with results" in log_type and "kb_search" not in shown_types:
                    print("📚 KNOWLEDGE BASE SEARCH:")
                    print(json.dumps(log_entry, indent=2))
                    print("-" * 80)
                    shown_types.add("kb_search")
                
                elif "Resolution attempted" in log_type and "resolution" not in shown_types:
                    print("✅ RESOLUTION ATTEMPT:")
                    print(json.dumps(log_entry, indent=2))
                    print("-" * 80)
                    shown_types.add("resolution")
                
                elif "Ticket escalated" in log_type and "escalation" not in shown_types:
                    print("🚨 ESCALATION:")
                    print(json.dumps(log_entry, indent=2))
                    print("-" * 80)
                    shown_types.add("escalation")
                
                elif "Conversation saved to database" in log_type and "persistence" not in shown_types:
                    print("💾 DATABASE PERSISTENCE:")
                    print(json.dumps(log_entry, indent=2))
                    print("-" * 80)
                    shown_types.add("persistence")
                
            except json.JSONDecodeError:
                continue
        
        if not shown_types:
            print("No structured log entries found. Run some conversations first.")
    else:
        print("No log files found. Run some conversations to generate logs.")
else:
    print("Logs directory not found. Run some conversations to generate logs.")
# Out:
# Reading logs from: logs\udahub_20251110.jsonl
#
# ...
# Total log entries: 230
#
# Sample log entries showing key events:
#
# --------------------------------------------------------------------------------
# 📊 SUPERVISOR ROUTING DECISION:
# {
#   "timestamp": "2025-11-10T15:08:45.581976",
#   "level": "INFO",
#   "logger": "udahub",
#   "message": "Supervisor routing decision",
#   "module": "workflow",
#   "function": "supervisor_node",
#   "line": 92,
#   "agent": "supervisor",
#   "thread_id": "3",
#   "classification": {
#     "issue_type": "other",
#     "urgency": "medium",
#     "confidence": 0.8,
#     "tags": "customer support, human agent",
#     "summary": "Customer requests to speak to a human agent for assistance."
#   },
#   "routing_decision": "resolver"
# }
# --------------------------------------------------------------------------------
# ✅ RESOLUTION ATTEMPT:
# {
#   "timestamp": "2025-11-10T15:08:45.602118",
#   "level": "INFO",
#   "logger": "udahub",
# ...

# %%
# Example 4: Test escalation
send_message(orchestrator, "I need to speak to a human agent", ticket_id="3", user_id="a4ab87")
# Out:
# 2025-11-10 11:22:19,250 - udahub - INFO - Processing user message
# User: I need to speak to a human agent
# 2025-11-10 11:22:19,254 - udahub - INFO - Supervisor node called
# 2025-11-10 11:22:19,254 - udahub - INFO - Supervisor routing decision
# 2025-11-10 11:22:19,267 - udahub - INFO - Conversation saved to database
# 2025-11-10 11:22:19,268 - udahub - INFO - Response generated
# Assistant: Subject: Escalation of Support Request - Ticket Reference: [Insert Ticket Number]
#
# Dear [Customer's Name],
#
# Thank you for reaching out to us. I understand that you were unable to find the relevant information in our knowledge base to address your question, and you would like to speak with a human support agent for further assistance.
#
# To summarize your issue: You have requested to escalate your inquiry to a human agent, as the information available did not meet your needs.
#
# ...

# %%
list(orchestrator.get_state_history(
    config = {
        "configurable": {
            "thread_id": "1",
        }
    }
))[0].values["messages"]
# Out:
# [HumanMessage(content="I can't log in to my CultPass account", additional_kwargs={}, response_metadata={}),
#  AIMessage(content="I couldn't find relevant information in our knowledge base to help with your question. Let me escalate this to a human support agent who can assist you better.", additional_kwargs={}, response_metadata={}),
# ...

# %% [markdown]
# ## Alternative: Interactive Chat Interface
#
# If you prefer the interactive chat interface (works better in terminal/command line):
# ```python
# # Note: This uses input() which may not work well in all Jupyter environments
# # chat_interface(orchestrator, "1")
# ```
#
# For Jupyter notebooks, use `send_message()` instead (see cell above).
